# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=np.arange(0,10)
y=np.arange(5,15)
x2=np.arange(10,20)
y2=np.arange(15,25)
x3=np.arange(0,10)
y3=np.arange(5,15)

# %%
plt.plot(x,y,'r',label="1st")
plt.plot(x[:5],y[:5]**2,'b',label="2nd")

plt.plot(x[5:],y[5:]**2,'b')
plt.plot()
plt.legend()
plt.show()
