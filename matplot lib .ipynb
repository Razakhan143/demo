# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=np.arange(0,10)
y=np.arange(5,15)
x2=np.arange(10,20)
y2=np.arange(15,25)
x3=np.arange(0,10)
y3=np.arange(5,15)

# %%
plt.figure(figsize=((5,5)),dpi=100)
plt.plot(x,y**1.9,label="1st",color="green",linewidth=2,marker='x',linestyle="--",markersize=10, markeredgecolor="red")
plt.plot(x[:6],y[:6]**2,'b',label="2nd")
plt.plot(x[5:],y[5:]**2,'b--')
plt.xticks((x**2)/8)
plt.yticks((y**2)*1.1)
plt.xlabel("price")
plt.ylabel("year")
plt.legend()
plt.savefig("graphh.png",dpi=3000)
plt.show()
